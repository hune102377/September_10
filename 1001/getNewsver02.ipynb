# %% [markdown]
# https://news.naver.com/newspaper/home?viewType=pc

# %%
# 모듈 불러오기
from urllib.request import urlopen #url 주소 호출 라이브러리
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
def getNews(num) :
    driver = webdriver.Chrome("./chromedriver")
    url = 'https://news.naver.com/'
    driver.get(url)
    driver.implicitly_wait(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 페이지에 있는 모든 href 받아오기
    list_url = []
    list_a = soup.find_all('a')
    for i in range(0, len(list_a)):
        if len(list_a[i]['href']) >= 1 :
            list_url.append(list_a[i]['href'])
    
    driver.close()   #현재 탭 닫기
    driver.quit()    #브라우저 닫기

    
    # 전체 list_url 에서 num 개의 뉴스 url만 따로 저장
    list_url_02 = []
    for j in range(91, (91 + (2 * num)), 2) :
        list_url_02.append(list_url[j])

    # 따로 저장한 url 에서 해당 기사의 제목, url, 기사 내용 추출
    for k in range(0, len(list_url_02)) :
        url = list_url_02[k]
        html = urlopen(url) # url 주소 html로 저장
        soup = BeautifulSoup(html.read(), 'html.parser') # html 데이터 BeautifulSoup으로 요약
        a = soup.contents[2].text
        t = a.split('\n')

        list_len = []
        for l in range(0, len(t)):
            list_len.append(len(t[l]))
        num = np.argmax(list_len)

        title = soup.title.text

        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
        print("기사 제목 :", title)
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
        print("상세 기사 :", url)
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
        print("기사 내용 :", t[num])
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

# %%
# 기사 5개 크롤링
getNews(5)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16692\407510678.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 기사 제목 : 이준석은 어디로···전당대회 지원이냐 신당 창당이냐
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 상세 기사 : https://n.news.naver.com/article/032/0003177854?cds=news_media_pc&type=editn
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# ...
